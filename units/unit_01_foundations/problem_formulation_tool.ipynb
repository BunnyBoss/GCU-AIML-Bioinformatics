# %% [markdown]
# <pre style="font-size: 15px; line-height: 1.2;">
# ---
# course_code: 02BMSBI24365
# course_title: AI and ML in Bioinformatics
# institution: Garden City University (GCU)
# program: M.Sc. Bioinformatics (Semester III)
# unit: Unit 1 — Foundations of Machine Learning for Bioinformatics
# submodule: 1.1 Introduction to Machine Learning in Bioinformatics
# document_type: Instructional Decision Framework
# ai_tier: Full AI (Learning Aid)
# ---
# </pre>

# %% [markdown]
# # 🧬 Biological Problem Solving: Decision Framework
#
# <small><b>Course Code:</b> 02BMSBI24365 | <b>Program:</b> M.Sc. Bioinformatics (Semester III) | <b>Institution:</b> Garden City University (GCU) | <b>AI Tier:</b> Full AI (Learning Aid)</small>
#
# ---
#
# *Instructions: Follow this step-by-step framework to translate a real-world biological problem into a Machine Learning strategy. By completing each step from top to bottom, you will systematically deduce exactly which type of ML model you need to build.*

# %% [markdown]
# <img src="./assets/decision_flowchart.png" alt="Decision Flowchart" width="600"/>

# %% [markdown]
# ---
# ### In-Class Live Walkthrough Example: Tumor Classification
# * **Biological Question:** Is a breast tissue biopsy sample benign or malignant?
# * **Data Source:** TCGA Breast Invasive Carcinoma (BRCA) Dataset.
# * **Features ($X$):** Clump thickness, uniformity of cell size, marginal adhesion, single epithelial cell size ($30$ numerical features).
# * **Target ($y$):** Tumor diagnosis (`0 = Benign`, `1 = Malignant`).
# * **Target Type:** Categorical (Discrete class).
# * **ML Task Deduced:** **Supervised Learning $\longrightarrow$ Binary Classification**.

# %% [markdown]
# ---
#
# ### 🔬 Step 1: Define the Biological Problem
# **What specific biological question are you trying to answer?**
# *(Example: "I want to predict whether a patient will respond positively to a chemotherapy drug based on their gene expression profile.")*

# %% [markdown]
# > **Answer:** *(Double-click this cell to edit and write your answer here)*

# %% [markdown]
# ---
# ### 💾 Step 2: Identify the Data Source
# **Where will you get the data to answer this question?**
# *(Example: "The BRCA (Breast Cancer) gene expression dataset from the TCGA Database.")*

# %% [markdown]
# > **Answer:** *(Double-click this cell to edit and write your answer here)*

# %% [markdown]
# ---
# ### 📊 Step 3: Analyze the Dataset Structure
# **Step 3A: Identify the Features ($X$)**
# What are the measurable inputs (clues) you will feed the machine?
# *(Example: "Expression levels of 50 different genes, patient age, tumor size.")*

# %% [markdown]
# > **Answer:** *(Double-click this cell to edit and write your answer here)*

# %% [markdown]
# <br>
#
# **Step 3B: Identify the Target ($y$)**
# What is the final answer you are trying to predict?
# *(Example: "Treatment Response (Yes or No).")*

# %% [markdown]
# > **Answer:** *(Double-click this cell to edit and write your answer here)*

# %% [markdown]
# <br>
#
# **Step 3C: Determine the Dimensions**
# How much data do you have to train the model? (Double-click to fill in the blanks)

# %% [markdown]
# > **Total Samples (Rows):** `[   ]`
# >
# > **Total Features (Columns):** `[   ]`

# %% [markdown]
# ---
# ### 🎯 Step 4: Classify the Target Variable
# **Look at your answer for Step 3B. What type of data is your Target?**
# *(Double-click and change `[ ]` to `[X]` for your choice)*
#
# - [ ] **Categorical:** The target is a distinct class or category (e.g., Benign vs. Malignant, True vs. False, Subtype A vs. Subtype B).
# - [ ] **Continuous:** The target is an infinite numerical value (e.g., Exact survival days, precise tumor weight in grams, exact blood pressure).

# %% [markdown]
# ---
# ### 🤖 Step 5: Final Decision - Choose the Machine Learning Task
# **Based on your logical deduction in Step 4, what Supervised Machine Learning task is required to solve your problem?**
# *(Double-click and change `[ ]` to `[X]` for your choice)*
#
# - [ ] **Classification Model** *(Select this if you chose Categorical in Step 4)*
# - [ ] **Regression Model** *(Select this if you chose Continuous in Step 4)*

# %% [markdown]
# ---
# ### 📌 Takeaway Practice Scenarios for Day 4
#
# Please duplicate this notebook or complete the 5 steps mentally for each of the following scenarios:
#
# #### 🧪 Scenario A: Epigenetic Aging Clock
# * **Context:** A longevity lab measures DNA methylation levels across $500$ CpG sites from blood samples to estimate a patient's true biological age in years.
# * **Your Task:** Identify $X$, $y$, data dimensions, target type (Continuous vs. Categorical), and deduce the ML task (Regression).
#
# #### 🧪 Scenario B: Antimicrobial Resistance (AMR) Detection
# * **Context:** A microbiology institute sequences whole genomes of *Mycobacterium tuberculosis* isolates to determine whether each isolate is resistant or susceptible to Rifampicin.
# * **Your Task:** Identify $X$ (SNP variants/mutations), $y$ (Resistant vs. Susceptible), target type, and deduce the ML task (Binary Classification).
#
# #### 🧪 Scenario C: Chemotherapy Drug Sensitivity ($IC_{50}$ Prediction)
# * **Context:** High-throughput screening measures RNA-seq expression of $1,000$ genes across cancer cell lines to predict the exact half-maximal inhibitory drug concentration ($IC_{50}$ in $\mu\text{M}$).
# * **Your Task:** Identify $X$, $y$, target type, and deduce the ML task (Regression).
#
# #### 🧪 Scenario D: Viral Subtype Discovery (Unsupervised Pattern Finding)
# * **Context:** Researchers sequence 200 unknown viral genomes during an outbreak without any prior disease classification to see if they naturally group into distinct viral families.
# * **Your Task:** Identify why this problem lacks a target variable $y$ and deduce the unsupervised task (Clustering / PCA).
